# %%
import pandas as pd

# %%
data = pd.read_csv('../data/Apartments.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           1393 non-null   float64
#  1   Payment        1393 non-null   object
#  2   Ownership      1393 non-null   object
#  3   Status         1393 non-null   object
#  4   Bedrooms       1393 non-null   float64
#  5   Bathrooms      1393 non-null   float64
#  6   PrivateGarden  1395 non-null   object
#  7   price          1393 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 87.3+ KB

# %%
data.sample(10)
# Out:
#        Area              Payment Ownership    Status  Bedrooms  Bathrooms  \
# 14    140.0  Cash or Installment    Resale     Ready       3.0        2.0
# 586   174.0                 Cash    Resale     Ready       3.0        3.0
# 735   145.0  Cash or Installment    Resale     Ready       3.0        2.0
# 289   165.0                 Cash    Resale     Ready       3.0        3.0
# 898   185.0          Installment    Resale     Ready       4.0        4.0
# 1027  109.0  Cash or Installment   Primary     Ready       2.0        1.0
# 364   165.0                 Cash   Primary     Ready       3.0        3.0
# 408   169.0                 Cash    Resale     Ready       3.0        3.0
# 1387  165.0          Installment    Resale  Off-plan       3.0        3.0
# 920   145.0          Installment    Resale  Off-plan       3.0        3.0
#
#      PrivateGarden           price
# 14             Yes   EGP 7,925,000
# 586             No   EGP 6,500,000
# 735            Yes   EGP 8,800,000
# 289            Yes   EGP 7,770,000
# 898             No  EGP 11,500,000
# 1027           Yes   EGP 7,800,000
# 364             No   EGP 5,950,000
# 408             No   EGP 8,500,000
# 1387            No   EGP 6,746,390
# 920            Yes  EGP 10,187,332

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1393 entries, 0 to 1394
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           1393 non-null   float64
#  1   Payment        1393 non-null   object
#  2   Ownership      1393 non-null   object
#  3   Status         1393 non-null   object
#  4   Bedrooms       1393 non-null   float64
#  5   Bathrooms      1393 non-null   float64
#  6   PrivateGarden  1393 non-null   object
#  7   price          1393 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 97.9+ KB

# %%
data['total_rooms'] = data['Bathrooms'] + data['Bedrooms']
data = data.drop(['Bathrooms','Bedrooms'],axis=1)

# %%
data['PrivateGarden'] = data['PrivateGarden'].map({'Yes':1,'No':0})

# %%
data['price'] = data['price'].replace(r'[^\d]','',regex = True).astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1393 entries, 0 to 1394
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           1393 non-null   float64
#  1   Payment        1393 non-null   object
#  2   Ownership      1393 non-null   object
#  3   Status         1393 non-null   object
#  4   PrivateGarden  1393 non-null   int64
#  5   price          1393 non-null   float64
#  6   total_rooms    1393 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 87.1+ KB

# %%
data = pd.get_dummies(data)
data.sample(5)
# Out:
#        Area  PrivateGarden      price  total_rooms  Payment_Cash  \
# 562   140.0              0  6400000.0          6.0          True
# 759   170.0              0  8283000.0          6.0         False
# 472   140.0              1  5500000.0          5.0          True
# 843   175.0              1  6300000.0          6.0          True
# 1394  160.0              1  7875000.0          5.0          True
#
#       Payment_Cash or Installment  Payment_Installment  Ownership_Primary  \
# 562                         False                False              False
# 759                         False                 True              False
# 472                         False                False               True
# 843                         False                False              False
# 1394                        False                False              False
#
#       Ownership_Resale  Status_Off-plan  Status_Ready
# 562               True            False          True
# 759               True             True         False
# 472              False            False          True
# 843               True            False          True
# 1394              True            False          True

# %% [markdown]
# We can delete one dummy variable from each feature so this variable will be the baseline and will be represented by the intercept in our regression model

# %%
data = data.drop(['Payment_Cash','Ownership_Resale', 'Status_Ready'], axis=1)

# %%
data.to_csv('../data/ProcessedData.csv', index = False)
