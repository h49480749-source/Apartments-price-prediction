# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/ProcessedData.csv')
original_data = pd.read_csv('../data/Apartments.csv')
data.head()
# Out:
#     Area  PrivateGarden      price  total_rooms  Payment_Cash or Installment  \
# 0  150.0              1  7000000.0          6.0                        False
# 1  235.0              0  7000000.0          6.0                        False
# 2  170.0              1  7732255.0          6.0                        False
# 3  135.0              0  5100000.0          4.0                        False
# 4  165.0              0  6850000.0          6.0                        False
#
#    Payment_Installment  Ownership_Primary  Status_Off-plan
# 0                False               True            False
# 1                False              False            False
# 2                 True               True             True
# 3                 True              False            False
# 4                False              False            False

# %% [markdown]
# Descriptive statistics is important to to gain some intuition about our data so that we can evaluate the prediction of our model

# %%
data.describe()
# Out:
#               Area  PrivateGarden         price  total_rooms
# count  1393.000000    1393.000000  1.393000e+03  1393.000000
# mean    161.288586       0.357502  7.696824e+06     5.623116
# std      28.306893       0.479436  2.498283e+06     0.891021
# min      65.000000       0.000000  3.730000e+06     2.000000
# 25%     145.000000       0.000000  6.200000e+06     5.000000
# 50%     160.000000       0.000000  7.037145e+06     6.000000
# 75%     170.000000       1.000000  8.200000e+06     6.000000
# max     300.000000       1.000000  2.200000e+07     8.000000

# %%
fig = plt.figure(figsize=(8,5))
sns.regplot(data=data,x='Area',y='price')
plt.show()

# %%
fig, axes = plt.subplots(3,2,figsize=(10,8))
sns.boxplot(data=data,x='total_rooms',y='price',ax=axes[0,0])
sns.boxplot(data=data,x='PrivateGarden',y='price',ax=axes[0,1])
sns.boxplot(x=original_data['Payment'],y=data['price'],ax=axes[1,0])
sns.boxplot(x=original_data['Ownership'],y=data['price'],ax=axes[1,1])
sns.boxplot(x=original_data['Status'],y=data['price'],ax=axes[2,0])

plt.tight_layout()
plt.show()
